# %% [markdown]
# # Colab DPO Run Notebook
#
# This notebook is a thin launch wrapper for `main.py`.
#
# - `batch` runs Version A.
# - `resume` skips completed runs.
# - Results are written under `results/runs/{experiment_id}/`.

# %%
# Optional: install dependencies in Colab before running.
# !pip install -r requirements.txt

from pathlib import Path
import subprocess
import sys

cmd = [sys.executable, 'main.py', 'batch', '--plan', 'configs/version_a.yaml', '--results-root', 'results', '--data-root', 'data']
subprocess.run(cmd, check=True)
